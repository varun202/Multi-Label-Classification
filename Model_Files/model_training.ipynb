# %% [markdown]
# ##**Build Model and add Convolutional layers**

# %%
import tensorflow as tf
#from tensorflow.keras.optimizers import SGD,adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Flatten, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
tf.__version__
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pandas as pd

# %%
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=(5, 5), activation="relu", input_shape=(128, 128,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters=64, kernel_size=(5, 5), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())

model.add(Dense(700, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(228, activation='sigmoid'))


model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 16)      1216
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 16)       0
#  )
#
#  dropout (Dropout)           (None, 62, 62, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 58, 58, 32)        12832
#
#  max_pooling2d_1 (MaxPooling  (None, 29, 29, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 29, 29, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          102464
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 700)               717500
#
#  dropout_4 (Dropout)         (None, 700)               0
#
#  dense_1 (Dense)             (None, 512)               358912
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 228)               116964
#
# =================================================================
# Total params: 1,361,152
# Trainable params: 1,361,152
# Non-trainable params: 0
# _________________________________________________________________

# %%
STEP_SIZE_TRAIN=train_dataset.n//train_dataset.batch_size
STEP_SIZE_VALID=validate_dataset.n//validate_dataset.batch_size
STEP_SIZE_TEST=test_dataset.n//test_dataset.batch_size

# %%
# Training the model
history = model.fit(train_dataset,                  
                    validation_data = validate_dataset,
                    epochs=10
)
# Out:
# Epoch 1/10
# 460/460 [==============================] - 184s 401ms/step - loss: 0.0821 - accuracy: 0.7179 - val_loss: 0.1438 - val_accuracy: 0.3020
# Epoch 2/10
# 460/460 [==============================] - 150s 327ms/step - loss: 0.0813 - accuracy: 0.7203 - val_loss: 0.1387 - val_accuracy: 0.3873
# Epoch 3/10
# 460/460 [==============================] - 147s 321ms/step - loss: 0.0805 - accuracy: 0.7166 - val_loss: 0.1425 - val_accuracy: 0.3173
# Epoch 4/10
# 460/460 [==============================] - 148s 322ms/step - loss: 0.0794 - accuracy: 0.7171 - val_loss: 0.1456 - val_accuracy: 0.3153
# Epoch 5/10
# 460/460 [==============================] - 148s 323ms/step - loss: 0.0786 - accuracy: 0.7196 - val_loss: 0.1429 - val_accuracy: 0.3407
# Epoch 6/10
# 460/460 [==============================] - 150s 326ms/step - loss: 0.0778 - accuracy: 0.7179 - val_loss: 0.1422 - val_accuracy: 0.3323
# Epoch 7/10
# 460/460 [==============================] - 149s 325ms/step - loss: 0.0772 - accuracy: 0.7139 - val_loss: 0.1444 - val_accuracy: 0.3153
# Epoch 8/10
# 460/460 [==============================] - 150s 327ms/step - loss: 0.0767 - accuracy: 0.7125 - val_loss: 0.1430 - val_accuracy: 0.3340
# Epoch 9/10
# 460/460 [==============================] - 150s 326ms/step - loss: 0.0763 - accuracy: 0.7139 - val_loss: 0.1454 - val_accuracy: 0.3043
# Epoch 10/10
# 460/460 [==============================] - 207s 450ms/step - loss: 0.0760 - accuracy: 0.7080 - val_loss: 0.1449 - val_accuracy: 0.3080
# '\nhistory = model.fit_generator(generator=train_dataset,\n                    steps_per_epoch=STEP_SIZE_TRAIN,\n                    validation_data=validate_dataset,\n                    validation_steps=STEP_SIZE_VALID,\n                    epochs=3\n)\n'
